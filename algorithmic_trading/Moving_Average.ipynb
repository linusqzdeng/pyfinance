# %%
import pandas as pd 
import numpy as np 
import pandas_datareader as web
import matplotlib.pyplot as plt 
from datetime import datetime

# %%
start = datetime(2006, 1, 1)
end = datetime(2021, 1, 1)
df = web.DataReader('AAPL', data_source='yahoo', start=start, end=end)
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2006-01-03    2.669643    2.580357    2.585000    2.669643  807234400.0
# 2006-01-04    2.713571    2.660714    2.683214    2.677500  619603600.0
# 2006-01-05    2.675000    2.633929    2.672500    2.656429  449422400.0
# 2006-01-06    2.739286    2.662500    2.687500    2.725000  704457600.0
# 2006-01-09    2.757143    2.705000    2.740357    2.716071  675040800.0
# ...                ...         ...         ...         ...          ...
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600.0
#
#              Adj Close
# Date
# 2006-01-03    2.299533
# 2006-01-04    2.306301
# ...

# %%
# %matplotlib inline
plt.style.use('ggplot')

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['Adj Close'], label='AAPL')
plt.title('Apple adjusted close price')
plt.xlabel('Date')
plt.ylabel('Adj. Close ($)')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# # Create a simple moving average with a 30-day window

# %%
df['30 MA'] = df['Adj Close'].rolling(window=30).mean()
df['100 MA'] = df['Adj Close'].rolling(window=100).mean()

df['100 MA'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Adj Close'], label='Adj. close')
plt.plot(df['30 MA'], label='30 MA')
plt.plot(df['100 MA'], label='100 MA')

plt.title('Adj Close, 30 MA and 100 MA')
plt.xlabel('Date')
plt.ylabel('Adj. Close ($)')
plt.legend(loc=0)
plt.show()
